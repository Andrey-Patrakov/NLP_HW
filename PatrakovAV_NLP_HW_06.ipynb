# %%
# !wget -O imdb.zip -qq --no-check-certificate "https://drive.google.com/uc?export=download&id=1vrQ5czMHoO3pEnmofFskymXMkq_u1dPc"
# !unzip imdb.zip
# !pip -q install eli5
# !pip -q install spacy
# !python -m spacy download en

# %% [markdown]
# Тут придется авторизировать запрос к гугл драйву, извините.

# %%
# # Install the PyDrive wrapper & import libraries.
# # This only needs to be done once per notebook.
# !pip install -U -q PyDrive
# from pydrive.auth import GoogleAuth
# from pydrive.drive import GoogleDrive
# from google.colab import auth
# from oauth2client.client import GoogleCredentials

# # Authenticate and create the PyDrive client.
# # This only needs to be done once per notebook.
# auth.authenticate_user()
# gauth = GoogleAuth()
# gauth.credentials = GoogleCredentials.get_application_default()
# drive = GoogleDrive(gauth)

# downloaded = drive.CreateFile({'id': '1d1-5FwxK53ePwygNWeG7jhsOWZbi5HOv'})
# downloaded.GetContentFile('train_docs.pkl')

# downloaded = drive.CreateFile({'id': '1MMOY477t965G0C5DtXeREVp0X85UaNq5'})
# downloaded.GetContentFile('test_docs.pkl')

# %% [markdown]
# # Классификация текстов
#
# Начнём с самого простого - анализа тональности текста.
#
# Будем классифицировать отзывы с IMDB на положительные/отрицательные.
#
# Датасет взят с http://ai.stanford.edu/~amaas/data/sentiment/

# %%
# !head train.tsv

# %%
import pandas as pd

train_df = pd.read_csv("train.tsv", delimiter="\t")
test_df = pd.read_csv("test.tsv", delimiter="\t")

print('Train size = {}'.format(len(train_df)))
print('Test size = {}'.format(len(test_df)))
# Out:
# Train size = 25000
# Test size = 25000

# %% [markdown]
# Посмотрите глазами на тексты? Какие есть зацепки, как определить, что это за сентимент?
#
# Самое простое, как всегда - найти ключевые слова.

# %%
#@title Начинаем классифицировать! { vertical-output: true, display-mode: "form" }
positive_words = 'love', 'great', 'best', 'wonderful' #@param {type:"raw"}
negative_words = 'worst', 'awful', '1/10', 'crap' #@param {type:"raw"}

positives_count = test_df.review.apply(lambda text: sum(word in text for word in positive_words))
negatives_count = test_df.review.apply(lambda text: sum(word in text for word in negative_words))
is_positive = positives_count > negatives_count
correct_count = (is_positive == test_df.is_positive).values.sum()

accuracy = correct_count / len(test_df)

print('Test accuracy = {:.2%}'.format(accuracy))
if accuracy > 0.71:
    from IPython.display import Image, display
    display(Image('https://s3.amazonaws.com/achgen360/t/rmmoZsub.png', width=500))
# Out:
# Test accuracy = 66.73%

# %% [markdown]
# **Задание** Придумайте хорошие ключевые слова или фразы и наберите хотя бы 71% точности на тесте (и не забудьте посмотреть на код классификации!)

# %%
positive_words = 'love', 'great', 'best', 'wonderful', 'excellent', 'favorite', 'enjoyable', 'compelling', 'classic' #@param {type:"raw"}
negative_words = 'worst', 'awful', '1/10', 'crap', 'worse', 'weak', 'flat', 'disappoint', 'terrible', 'meaningless', 'lame' #@param {type:"raw"}

positives_count = test_df.review.apply(lambda text: sum(word in text for word in positive_words))
negatives_count = test_df.review.apply(lambda text: sum(word in text for word in negative_words))
is_positive = positives_count > negatives_count
correct_count = (is_positive == test_df.is_positive).values.sum()

accuracy = correct_count / len(test_df)

print('Test accuracy = {:.2%}'.format(accuracy))
if accuracy > 0.71:
    try:
        from IPython.display import Image, display
        display(Image('https://s3.amazonaws.com/achgen360/t/rmmoZsub.png', width=500))
    except:
        print("Картинку видимо удалили, поэтому я вставил этот текст")
# Out:
# Test accuracy = 71.05%
# Картинку видимо удалили, поэтому я вставил этот текст

# %% [markdown]
# **Задание** Кому-нибудь нравятся эти `<br /><br />`? Лично мне - нет. Напишите регулярку, которая будет их удалять

# %%
import re

pattern = re.compile('<br />')

print(train_df['review'].iloc[3])
print(pattern.subn(' ', train_df['review'].iloc[3])[0])
# Out:
# Spoilers ahead if you want to call them that...<br /><br />I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...<br /><br />THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or "effort".<br /><br />THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of "Woah, you totally freaked me out" and "I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?". It makes me want to rip out all my hair, one strand at a time and feed it to myself.<br /><br />THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards...<br /><br />THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The "Woah you totally freaked me out" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone.<br /><br />TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it.<br /><br />Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it.<br /><br />Signing off... Amanda Christmas
# Spoilers ahead if you want to call them that...  I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...  THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or "effort".  THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of "Woah, you totally freaked me out" and "I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?". It makes me want to rip out all my hair, one strand at a time and feed it to myself.  THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards...  THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The "Woah you totally freaked me out" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone.  TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it.  Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it.  Signing off... Amanda Christmas

# %%
import re

pattern = re.compile('<\s*br\s*\/?>')
print(train_df['review'].iloc[3])
print(pattern.subn(' ', train_df['review'].iloc[3])[0])
# Out:
# Spoilers ahead if you want to call them that...<br /><br />I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...<br /><br />THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or "effort".<br /><br />THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of "Woah, you totally freaked me out" and "I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?". It makes me want to rip out all my hair, one strand at a time and feed it to myself.<br /><br />THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards...<br /><br />THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The "Woah you totally freaked me out" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone.<br /><br />TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it.<br /><br />Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it.<br /><br />Signing off... Amanda Christmas
# Spoilers ahead if you want to call them that...  I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...  THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or "effort".  THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of "Woah, you totally freaked me out" and "I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?". It makes me want to rip out all my hair, one strand at a time and feed it to myself.  THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards...  THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The "Woah you totally freaked me out" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone.  TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it.  Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it.  Signing off... Amanda Christmas

# %% [markdown]
# Применим ее:

# %%
train_df['review'] = train_df['review'].apply(lambda text: pattern.subn(' ', text)[0])
test_df['review'] = test_df['review'].apply(lambda text: pattern.subn(' ', text)[0])

# %% [markdown]
# Пора переходить к машинке!
#
# Как будем представлять текст? Проще всего - мешком слов.
#
# Заведём большой-большой словарь - список всех слов в обучающей выборке. Тогда каждое предложение можно представить в виде вектора, в котором будет записано, сколько раз встретилось каждое из возможных слов:
#
# ![bow](https://raw.githubusercontent.com/DanAnastasyev/DeepNLP-Course/master/Week%2001/Images/BOW.png)
#
# Простой и приятный способ сделать это - запихнуть тексты в `CountVectorizer`.
#
# Он имеет такую сигнатуру:
#
# ```python
# CountVectorizer(input='content', encoding='utf-8', decode_error='strict', strip_accents=None, lowercase=True, preprocessor=None, tokenizer=None, stop_words=None, token_pattern=r'(?u)\b\w\w+\b', ngram_range=(1, 1), analyzer='word', max_df=1.0, min_df=1, max_features=None, vocabulary=None, binary=False, dtype=<class ‘numpy.int64'>)
# ```
#
# Для начала обратим внимание на параметры `lowercase=True` и `max_df=1.0, min_df=1, max_features=None` - они про то, что по умолчанию все слова будут приводиться к нижнему регистру и в словарь попадут все слова, встречавшиеся в текстах.
#
# При желании можно было бы убрать слишком редкие или слишком частотные слова - пока не будем этого делать.
#
# Посмотрим на простом примере, как он будет работать:

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

dummy_data = ['The movie was excellent',
              'the movie was awful']

dummy_matrix = vectorizer.fit_transform(dummy_data)

print(dummy_matrix.toarray())
print(vectorizer.get_feature_names_out())
# Out:
# [[0 1 1 1 1]
#  [1 0 1 1 1]]
# ['awful' 'excellent' 'movie' 'the' 'was']

# %% [markdown]
# *Как именно vectorizer определяет границы слов? Обратите внимание на параметр `token_pattern=r'(?u)\b\w\w+\b'` - как он будет работать?*
#
# Запустим его на реальных данных:

# %%
vectorizer = CountVectorizer()
vectorizer.fit(train_df['review'].values)
# Out:
# CountVectorizer()

# %% [markdown]
# Посмотрим на слова, попавшие в словарь:

# %%
vectorizer.get_feature_names()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['00',
#  '000',
#  '0000000000001',
#  '00001',
#  '00015',
#  '000s',
#  '001',
#  '003830',
#  '006',
#  '007',
#  '0079',
#  '0080',
#  '0083',
#  '0093638',
#  '00am',
#  '00pm',
#  '00s',
#  '01',
#  '01pm',
#  '02',
#  '020410',
#  '029',
#  '03',
#  '04',
#  '041',
#  '05',
#  '050',
#  '06',
#  '06th',
#  '07',
#  '08',
#  '087',
#  '089',
#  '08th',
#  '09',
#  '0f',
#  '0ne',
#  '0r',
#  '0s',
#  '10',
#  '100',
#  '1000',
#  '1000000',
#  '10000000000000',
#  '1000lb',
#  '1000s',
#  '1001',
#  '100b',
#  '100k',
#  '100m',
#  '100min',
#  '100mph',
#  '100s',
#  '100th',
#  '100x',
#  '100yards',
#  '101',
#  '101st',
#  '102',
#  '102nd',
#  '103',
#  '104',
#  '1040',
#  '1040a',
#  '1040s',
#  '105',
#  '1050',
#  '105lbs',
#  '106',
#  '106min',
#  '107',
#  '108',
#  '109',
#  '10am',
#  '10lines',
#  '10mil',
#  '10min',
#  '10minutes',
#  '10p',
#  '10pm',
#  '10s',
#  '10star',
#  '10th',
#  '10x',
#  '10yr',
#  '11',
#  '110',
#  '1100',
#  '11001001',
#  '1100ad',
#  '111',
#  '112',
#  '1138',
#  '114',
#  '1146',
#  '115',
#  '116',
#  '117',
#  '11f',
#  '11m',
#  '11th',
#  '12',
#  '120',
#  '1200',
#  '1200f',
#  '1201',
#  '1202',
#  '123',
#  '12383499143743701',
#  '125',
#  '125m',
#  '127',
#  '128',
#  '12a',
#  '12hr',
#  '12m',
#  '12mm',
#  '12s',
#  '12th',
#  '13',
#  '130',
#  '1300',
#  '1300s',
#  '131',
#  '1318',
#  '132',
#  '134',
#  '135',
#  '135m',
#  '136',
#  '137',
#  '138',
#  '139',
#  '13k',
#  '13s',
#  '13th',
#  '14',
#  '140',
#  '1408',
#  '140hp',
#  '1415',
#  '142',
#  '145',
#  '1454',
#  '146',
#  '147',
#  '1473',
#  '149',
#  '1492',
#  '14a',
#  '14ieme',
#  '14s',
#  '14th',
#  '14yr',
#  '14ème',
#  '15',
#  '150',
#  '1500',
#  '1500s',
#  '150_worst_cases_of_nepotism',
#  '150k',
#  '150m',
#  '151',
#  '152',
#  '153',
#  '1547',
#  '155',
#  '156',
#  '1561',
#  '157',
#  '158',
#  '1594',
#  '15mins',
#  '15minutes',
#  '15s',
#  '15th',
#  '16',
#  '160',
#  '1600',
#  '1600s',
#  '160lbs',
#  '161',
#  '1610',
#  '163',
#  '164',
#  '165',
#  '166',
#  '1660s',
#  '168',
#  '169',
#  '1692',
#  '16ieme',
#  '16k',
#  '16mm',
#  '16s',
#  '16th',
#  '16x9',
#  '16ème',
#  '16éme',
#  '17',
#  '170',
#  '1700',
#  '1700s',
#  '1701',
#  '171',
#  '175',
#  '177',
#  '1775',
#  '1780s',
#  '1790s',
#  '1794',
#  '1798',
#  '17million',
#  '17th',
#  '18',
#  '180',
#  '1800',
#  '1800mph',
#  '1800s',
#  '1801',
#  '1805',
#  '1809',
#  '180d',
#  '1812',
#  '1813',
#  '18137',
#  '1814',
#  '1816',
#  '1820',
#  '1824',
#  '183',
#  '1830',
#  '1832',
#  '1836',
#  '1837',
#  '1838',
#  '1839',
#  '1840',
#  '1840s',
#  '1844',
#  '1846',
#  '1847',
#  '185',
#  '1850',
#  '1850ies',
#  '1850s',
#  '1852',
#  '1853',
#  '1854',
#  '1855',
#  '1859',
#  '1860',
#  '1860s',
#  '1861',
#  '1862',
#  '1863',
#  '1864',
#  '1865',
#  '1870',
#  '1870s',
#  '1871',
#  '1873',
#  '1874',
#  '1875',
#  '1876',
#  '188',
#  '1880',
#  '1880s',
#  '1881',
#  '1886',
#  '1887',
#  '1888',
#  '1889',
#  '188o',
#  '1890',
#  '1890s',
#  '1892',
#  '1893',
#  '1894',
#  '1895',
#  '1896',
#  '1897',
#  '1898',
#  '1899',
#  '18a',
#  '18s',
#  '18th',
#  '18year',
#  '19',
#  '190',
#  '1900',
#  '1900s',
#  '1901',
#  '1902',
#  '1903',
#  '1904',
#  '1905',
#  '1906',
#  '1907',
#  '1908',
#  '1909',
#  '1910',
#  '1910s',
#  '1911',
#  '1912',
#  '1913',
#  '1914',
#  '1915',
#  '1916',
#  '1917',
#  '1918',
#  '1919',
#  '192',
#  '1920',
#  '1920ies',
#  '1920s',
#  '1921',
#  '1922',
#  '1923',
#  '1924',
#  '1925',
#  '1926',
#  '1927',
#  '1928',
#  '1929',
#  '1930',
#  '1930ies',
#  '1930s',
#  '1931',
#  '1932',
#  '1933',
#  '1934',
#  '1935',
#  '1936',
#  '1937',
#  '1938',
#  '1939',
#  '193o',
#  '194',
#  '1940',
#  '1940s',
#  '1941',
#  '1942',
#  '1943',
#  '1944',
#  '1945',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '1949er',
#  '195',
#  '1950',
#  '1950s',
#  '1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '1960',
#  '1960s',
#  '1961',
#  '1961s',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '197',
#  '1970',
#  '1970ies',
#  '1970s',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '19796',
#  '197o',
#  '1980',
#  '1980ies',
#  '1980s',
#  '1981',
#  '1982',
#  '1982s',
#  '1983',
#  '1983s',
#  '1984',
#  '1984ish',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1990s',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '19k',
#  '19th',
#  '19thc',
#  '1am',
#  '1and',
#  '1d',
#  '1h',
#  '1h30',
#  '1h40',
#  '1h40m',
#  '1h53',
#  '1hour',
#  '1hr',
#  '1million',
#  '1min',
#  '1mln',
#  '1o',
#  '1s',
#  '1st',
#  '1ton',
#  '1tv',
#  '1½',
#  '1ç',
#  '20',
#  '200',
#  '2000',
#  '20000',
#  '20001',
#  '2000ad',
#  '2000s',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2004s',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '200ft',
#  '200th',
#  '201',
#  '2010',
#  '2012',
#  '2013',
#  '2015',
#  '2017',
#  '2019',
#  '2020',
#  '2022',
#  '2023',
#  '2030',
#  '2031',
#  '2033',
#  '2035',
#  '2036',
#  '2038',
#  '204',
#  '2040',
#  '2044',
#  '2046',
#  '2047',
#  '2050',
#  '2053',
#  '2054',
#  '206',
#  '2060',
#  '2070',
#  '2080',
#  '209',
#  '2090',
#  '20c',
#  '20ft',
#  '20k',
#  '20m',
#  '20mins',
#  '20minutes',
#  '20mn',
#  '20p',
#  '20perr',
#  '20s',
#  '20th',
#  '20ties',
#  '20widow',
#  '20x',
#  '20year',
#  '20yrs',
#  '21',
#  '210',
#  '2100',
#  '214',
#  '215',
#  '2151',
#  '216',
#  '21699',
#  '21849889',
#  '21849890',
#  '21849907',
#  '21st',
#  '22',
#  '220',
#  '2200',
#  '221',
#  '2210',
#  '22101',
#  '222',
#  '223',
#  '225',
#  '2257',
#  '225mins',
#  '227',
#  '22d',
#  '22h45',
#  '22nd',
#  '23',
#  '230lbs',
#  '230mph',
#  '231',
#  '232',
#  '233',
#  '236',
#  '237',
#  '23d',
#  '23rd',
#  '24',
#  '240',
#  '2400',
#  '241',
#  '242',
#  '248',
#  '2480',
#  '249',
#  '24m30s',
#  '24th',
#  '24years',
#  '25',
#  '250',
#  '2500',
#  '250000',
#  '25million',
#  '25mins',
#  '25s',
#  '25th',
#  '25yo',
#  '25yrs',
#  '26',
#  '260',
#  '2600',
#  '261k',
#  '262',
#  '2642',
#  '269',
#  '26th',
#  '27',
#  '270',
#  '272',
#  '273',
#  '274',
#  '275',
#  '2772',
#  '278',
#  '27th',
#  '27x41',
#  '28',
#  '280',
#  '285',
#  '28th',
#  '29',
#  '29th',
#  '2am',
#  '2d',
#  '2fast',
#  '2furious',
#  '2h',
#  '2h30',
#  '2hour',
#  '2hours',
#  '2hr',
#  '2hrs',
#  '2in',
#  '2inch',
#  '2k',
#  '2more',
#  '2nd',
#  '2oo4',
#  '2oo5',
#  '2pac',
#  '2point4',
#  '2s',
#  '2x4',
#  '30',
#  '300',
#  '3000',
#  '300ad',
#  '300c',
#  '300lbs',
#  '300mln',
#  '3012',
#  '303',
#  '305',
#  '30am',
#  '30ish',
#  '30k',
#  '30lbs',
#  '30min',
#  '30mins',
#  '30pm',
#  '30s',
#  '30something',
#  '30th',
#  '30ties',
#  '31',
#  '3199',
#  '31st',
#  '32',
#  '3200',
#  '320x180',
#  '32lb',
#  '32nd',
#  '33',
#  '330am',
#  '330mins',
#  '332960073452',
#  '336th',
#  '33m',
#  '34',
#  '345',
#  '3462',
#  '34th',
#  '35',
#  '350',
#  '3500',
#  '3516',
#  '356',
#  '357',
#  '35c',
#  '35mins',
#  '35mm',
#  '35pm',
#  '35th',
#  '35yr',
#  '36',
#  '360',
#  '365',
#  '36th',
#  '37',
#  '370',
#  '372',
#  '378',
#  '38',
#  '38k',
#  '38th',
#  '39',
#  '395',
#  '39th',
#  '3am',
#  '3bs',
#  '3d',
#  '3dvd',
#  '3k',
#  '3lbs',
#  '3m',
#  '3mins',
#  '3p',
#  '3p0',
#  '3pm',
#  '3po',
#  '3rd',
#  '3rds',
#  '3th',
#  '3who',
#  '3x5',
#  '3yrs',
#  '40',
#  '400',
#  '4000',
#  '401k',
#  '405',
#  '409',
#  '40am',
#  '40min',
#  '40mins',
#  '40mph',
#  '40s',
#  '40th',
#  '41',
#  '42',
#  '420',
#  '425',
#  '428',
#  '42nd',
#  '43',
#  '430',
#  '44',
#  '440',
#  '442nd',
#  '44c',
#  '44yrs',
#  '45',
#  '450',
#  '4500',
#  '451',
#  '454',
#  '45am',
#  '45min',
#  '45mins',
#  '45s',
#  '46',
#  '465',
#  '469',
#  '47',
#  '475',
#  '477',
#  '47s',
#  '48',
#  '480m',
#  '480p',
#  '48hrs',
#  '49',
#  '498',
#  '49th',
#  '4am',
#  '4cylinder',
#  '4d',
#  '4eva',
#  '4ever',
#  '4f',
#  '4h',
#  '4hrs',
#  '4k',
#  '4kids',
#  '4m',
#  '4o',
#  '4pm',
#  '4th',
#  '4w',
#  '4ward',
#  '4x',
#  '4x4',
#  '50',
#  '500',
#  '5000',
#  '500000',
#  '500ad',
#  '500db',
#  '500lbs',
#  '502',
#  '50c',
#  '50ft',
#  '50ies',
#  '50ish',
#  '50k',
#  '50min',
#  '50mins',
#  '50s',
#  '50th',
#  '50usd',
#  '51',
#  '51b',
#  '51st',
#  '52',
#  '5200',
#  '5250',
#  '529',
#  '52s',
#  '53',
#  '53m',
#  '54',
#  '5400',
#  '540i',
#  '54th',
#  '55',
#  '5539',
#  '555',
#  '55th',
#  '56',
#  '57',
#  '571',
#  '576',
#  '578',
#  '57d',
#  '58',
#  '58th',
#  '59',
#  '598947',
#  '59th',
#  '5hrs',
#  '5ive',
#  '5kph',
#  '5million',
#  '5min',
#  '5mins',
#  '5s',
#  '5seconds',
#  '5th',
#  '5x',
#  '5x5',
#  '5years',
#  '5yo',
#  '5yrs',
#  '60',
#  '600',
#  '6000',
#  '607',
#  '608',
#  '60ies',
#  '60ish',
#  '60mph',
#  '60s',
#  '60th',
#  '60ties',
#  '61',
#  '618',
#  '62',
#  '6200',
#  '62229249',
#  '63',
#  '637',
#  '63rd',
#  '64',
#  '65',
#  '65m',
#  '66',
#  '660',
#  '666',
#  '66er',
#  '67',
#  '6723',
#  '67th',
#  '68',
#  '68th',
#  '69',
#  '69th',
#  '6am',
#  '6b',
#  '6ft',
#  '6hours',
#  '6k',
#  '6million',
#  '6pm',
#  '6th',
#  '6wks',
#  '6yo',
#  '70',
#  '700',
#  '701',
#  '707',
#  '70ies',
#  '70m',
#  '70mm',
#  '70s',
#  '70th',
#  '71',
#  '713',
#  '72',
#  '72nd',
#  '73',
#  '7300',
#  '735',
#  '737',
#  '74',
#  '740',
#  '740il',
#  '747',
#  '747s',
#  '74th',
#  '75',
#  '750',
#  '75054',
#  '75c',
#  '75m',
#  '76',
#  '7600',
#  '77',
#  '78',
#  '788',
#  '78rpm',
#  '79',
#  '79th',
#  '7days',
#  '7even',
#  '7eventy',
#  '7ft',
#  '7ish',
#  '7mm',
#  '7th',
#  '7½th',
#  '80',
#  '800',
#  '8000',
#  '80ies',
#  '80ish',
#  '80min',
#  '80s',
#  '80yr',
#  '81',
#  '817',
#  '819',
#  '82',
#  '820',
#  '8217',
#  '8230',
#  '83',
#  '84',
#  '849',
#  '84f',
#  '84s',
#  '85',
#  '850',
#  '850pm',
#  '86',
#  '86s',
#  '87',
#  '8700',
#  '8763',
#  '878',
#  '87minutes',
#  '88',
#  '88min',
#  '89',
#  '89or',
#  '89s',
#  '8bit',
#  '8ftdf',
#  '8k',
#  '8mm',
#  '8o',
#  '8p',
#  '8pm',
#  '8star',
#  '8th',
#  '8u',
#  '8½',
#  '90',
#  '900',
#  '9000',
#  '90210',
#  '905',
#  '90c',
#  '90ish',
#  '90min',
#  '90mins',
#  '90s',
#  '91',
#  '911',
#  '914',
#  '917',
#  '92',
#  '921',
#  '92fs',
#  '92nd',
#  '93',
#  '937',
#  '94',
#  '9484',
#  '94s',
#  '94th',
#  '95',
#  '950',
#  '95th',
#  '96',
#  '97',
#  '970',
#  '974th',
#  '978',
#  '98',
#  '987',
#  '98minutes',
#  '99',
#  '998',
#  '999',
#  '9999',
#  '99cents',
#  '99p',
#  '99½',
#  '9_',
#  '9am',
#  '9as',
#  '9do',
#  '9ers',
#  '9is',
#  '9lbs',
#  '9mm',
#  ...]

# %% [markdown]
# Попробуем кого-нибудь таки сконвертировать

# %%
vectorizer.transform([train_df['review'].iloc[3]])
# Out:
# <1x74849 sparse matrix of type '<class 'numpy.int64'>'
# 	with 206 stored elements in Compressed Sparse Row format>

# %% [markdown]
# То, что и хотели - вектор с bow (т.е. bag-of-words) представлением исходного текста.
#
# И чем эта информация может помочь? Ну, всё тем же - какие-то слова носят положительный окрас, какие-то - отрицательный. Большинство вообще нейтральный, да.
#
# ![bow with weights](https://github.com/DanAnastasyev/DeepNLP-Course/raw/master/Week%2001/Images/BOW_weights.png)
#
# Хочется, наверное, подобрать коэффициенты, которые будут определять уровень окраса, да? Подбирать нужно по обучающей выборке, а не как мы перед этим делали.
#
# Например, для выборки
# ```
# 1   The movie was excellent
# 0   the movie was awful
# ```
# легко подобрать коэффициенты на глазок: что-нибудь вроде `+1` для `excellent`,  `-1` для `awful` и по нулям всем остальным.
#
# Построим линейную модель, которая станет этим заниматься. Она будет учиться строить разделяющую гиперплоскость в пространстве bow-векторов.
#
# Проверим, как справится логистическая регрессия с нашей супер-выборкой из пары предложений

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

dummy_data = ['The movie was excellent',
              'the movie was awful']
dummy_labels = [1, 0]

vectorizer = CountVectorizer()
classifier = LogisticRegression(max_iter=1000)

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(dummy_data, dummy_labels)

print(vectorizer.get_feature_names_out())
print(classifier.coef_)
# Out:
# ['awful' 'excellent' 'movie' 'the' 'was']
# [[-0.40104279  0.40104279  0.          0.          0.        ]]

# %% [markdown]
# Получилось что надо.
#
# Запустим теперь её на реальных данных.

# %%
model.fit(train_df['review'], train_df['is_positive'])
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()),
#                 ('classifier', LogisticRegression(max_iter=1000))])

# %%
from sklearn.metrics import accuracy_score

def eval_model(model, test_df):
    preds = model.predict(test_df['review'])
    print('Test accuracy = {:.2%}'.format(accuracy_score(test_df['is_positive'], preds)))
    
eval_model(model, test_df)
# Out:
# Test accuracy = 86.66%

# %% [markdown]
# Прогресс!
#
# Хочется как-то посмотреть, что заинтересовало классификатор. К счастью, сделать это совсем просто:

# %%
import eli5
eli5.show_weights(classifier, vec=vectorizer, top=40)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.585
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         refreshing
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.411
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         wonderfully
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.52%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.354
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         erotic
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.296
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         funniest
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.02%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.288
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         perfect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.282
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         excellent
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.279
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         carrey
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.260
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         superb
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.250
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         surprisingly
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.249
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         appreciated
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.219
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         flawless
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.192
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         flight
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.187
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vengeance
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.163
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         units
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 86.98%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 37795 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.07%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 37015 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.152
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dreadful
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.02%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.159
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         photo
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.200
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mst3k
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.212
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mediocre
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.231
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         alright
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.232
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         save
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">

# %% [markdown]
# Посмотрим на конкретные примеры его работы:

# %%
print('Positive' if test_df['is_positive'].iloc[1] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[1], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Positive
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>1.000</b>, score <b>16.248</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +16.202
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.045
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 97.40%); opacity: 0.80" title="-0.020">this</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.75%); opacity: 0.81" title="0.040">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 81.24%); opacity: 0.87" title="0.334">both</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.07%); opacity: 0.81" title="-0.049">an</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 67.11%); opacity: 0.95" title="0.745">entertaining</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.74%); opacity: 0.82" title="0.086">and</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.985">touching</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.02%); opacity: 0.81" title="-0.050">version</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.02%); opacity: 0.81" title="-0.065">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.42%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 78.15%); opacity: 0.88" title="0.415">classic</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.85%); opacity: 0.85" title="0.223">tale</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 85.95%); opacity: 0.84" title="0.221">also</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.66%); opacity: 0.84" title="0.205">quite</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.83%); opacity: 0.85" title="0.270">intelligent</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(0, 100.00%, 86.82%); opacity: 0.84" title="-0.202">not</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.02%); opacity: 0.81" title="-0.065">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.42%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> &#x27;</span><span style="background-color: hsl(0, 100.00%, 99.65%); opacity: 0.80" title="-0.001">me</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.63%); opacity: 0.82" title="0.105">tarzan</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 87.34%); opacity: 0.84" title="0.190">you</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.98%); opacity: 0.82" title="0.099">jane</span><span style="opacity: 0.80">&#x27; </span><span style="background-color: hsl(120, 100.00%, 93.61%); opacity: 0.81" title="0.072">school</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.27%); opacity: 0.80" title="-0.011">at</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.47%); opacity: 0.80" title="0.002">all</span><span style="opacity: 0.80">.  </span><span style="background-color: hsl(120, 100.00%, 90.53%); opacity: 0.83" title="0.126">it</span><span style="opacity: 0.80">&#x27;s </span><span style="background-color: hsl(120, 100.00%, 96.42%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.03%); opacity: 0.85" title="0.265">famous</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.67%); opacity: 0.81" title="0.041">story</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.02%); opacity: 0.81" title ...

# %%
print('Positive' if test_df['is_positive'].iloc[6] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[6], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Negative
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-9.800</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.045
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -9.845
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 97.77%); opacity: 0.80" title="-0.020">this</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.52%); opacity: 0.80" title="0.023">movie</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.36%); opacity: 0.81" title="0.040">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 64.18%); opacity: 0.97" title="-1.052">terrible</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 91.90%); opacity: 0.82" title="0.126">it</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.83%); opacity: 0.81" title="-0.066">was</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.21%); opacity: 0.81" title="0.059">so</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.17%); opacity: 0.80" title="-0.015">difficult</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.79%); opacity: 0.80" title="-0.008">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.63%); opacity: 0.83" title="-0.155">believe</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.18%); opacity: 0.80" title="-0.015">that</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 73.88%); opacity: 0.91" title="-0.670">katie</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.55%); opacity: 0.81" title="0.091">became</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 78.18%); opacity: 0.88" title="0.518">heartfelt</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.77%); opacity: 0.80" title="0.001">teenager</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.19%); opacity: 0.80" title="0.015">with</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.94%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 87.96%); opacity: 0.84" title="-0.222">power</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.79%); opacity: 0.80" title="-0.008">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-1.232">save</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.94%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.07%); opacity: 0.80" title="0.006">pity</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.27%); opacity: 0.86" title="0.354">chinese</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.52%); opacity: 0.80" title="0.023">people</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 96.94%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.52%); opacity: 0.80" title="0.023">movie</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 87.27%); opacity: 0.84" title="-0.240">didn</span><span style="opacity: 0.80">&#x27;t </span><span style="background-color: hsl(0, 100.00%, 97.82%); opacity: 0.80" title="-0.019">show</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.51%); opacity: 0.83" title="-0.158">any</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.22%); opacity: 0.83" title="-0.215">convin ...

# %% [markdown]
# Посмотрим на примеры неправильной классификации, наконец:

# %%
import numpy as np

preds = model.predict(test_df['review'])
incorrect_pred_index = np.random.choice(np.where(preds != test_df['is_positive'])[0])

eli5.show_prediction(classifier, test_df['review'].iloc[incorrect_pred_index],
                     vec=vectorizer, targets=['positive'], target_names=['negative', 'positive'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.917</b>, score <b>2.403</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.358
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.045
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 83.86%); opacity: 0.85" title="-0.298">frankie</span><span style="opacity: 0.80"> muniz </span><span style="background-color: hsl(120, 100.00%, 91.62%); opacity: 0.82" title="0.117">plays</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.15%); opacity: 0.82" title="0.126">jason</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.62%); opacity: 0.83" title="0.137">who</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.03%); opacity: 0.81" title="0.040">is</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 91.59%); opacity: 0.82" title="0.117">high</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.04%); opacity: 0.81" title="0.072">school</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 83.54%); opacity: 0.86" title="-0.306">student</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(120, 100.00%, 93.81%); opacity: 0.81" title="0.076">his</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 74.13%); opacity: 0.91" title="-0.583">biggest</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 73.89%); opacity: 0.91" title="-0.591">problem</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.03%); opacity: 0.81" title="0.040">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.81%); opacity: 0.81" title="0.076">his</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.58%); opacity: 0.84" title="0.229">life</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.03%); opacity: 0.81" title="0.040">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 87.91%); opacity: 0.84" title="-0.197">built</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.91%); opacity: 0.81" title="-0.028">on</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.16%); opacity: 0.86" title="0.316">small</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.76%); opacity: 0.80" title="-0.018">or</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.30%); opacity: 0.80" title="-0.012">big</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 79.99%); opacity: 0.87" title="-0.404">lies</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.01%); opacity: 0.80" title="-0.015">that</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.62%); opacity: 0.80" title="0.019">puts</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.17%); opacity: 0.83" title="0.147">him</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.28%); opacity: 0.81" title="0.051">into</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 83.04%); opacity: 0.86" title="-0.319">trouble</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 81.20%); opacity: 0.87" title="0.370">most</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.23%); opacity: 0.84" title="0.237">times</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(0, 100.00%, 88.25%); opacity: 0.83" title="-0.189">however</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 97.69%); opacity: 0.80" title="0.018">he</span>< ...

# %% [markdown]
# ## Придумываем новые признаки

# %% [markdown]
# ### Tf-idf
#
# Сейчас мы на все слова смотрим с одинаковым весом - хотя какие-то из них более редкие, какие-то более частые, и эта частотность - полезная, вообще говоря, информация.
#
# Самый простой способ добавить статистическую информацию о частотностях - сделать *tf-idf* взвешивание:
#
# $$\text{tf-idf}(t, d) = \text{tf}(t, d) \times \text{idf}(t)$$
#
# *tf* - term-frequency - частотность слова `t` в конкретном документе `d` (рецензии в нашем случае). Это ровно то, что мы уже считали.
#
# *idf* - inverse document-frequency - коэффициент, который тем больше, чем в меньшем числе документов встречалось данное слово. Считается как-нибудь так:
# $$\text{idf}(t) = \text{log}\frac{1 + n_d}{1 + n_{d(t)}} + 1$$
# где $n_d$ - число всех документов, а $n_{d(t)}$ - число документов со словом `t`.
#
# Использовать его просто - нужно заменить `CountVectorizer` на `TfidfVectorizer`.
#
# **Задание** Попробуйте запустить `TfidfVectorizer`. Посмотрите на ошибки, которые он научился исправлять, и на ошибки, которые он начал делать - по сравнению с `CountVectorizer`.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
classifier = LogisticRegression(max_iter=1000)

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 88.28%

# %%
eli5.show_weights(classifier, vec=vectorizer, top=40)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.553
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         great
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.153
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         excellent
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         best
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.814
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         perfect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.653
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         wonderful
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.132
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         amazing
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.000
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         well
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.837
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         loved
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.772
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         favorite
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.769
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fun
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.757
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         love
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.753
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         today
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.506
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         enjoyed
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 89.84%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 37454 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 90.03%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 37356 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 90.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.413
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         supposed
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.433
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         lame
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.462
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         disappointing
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.497
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         disappointment
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.499
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         even
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.501
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mess
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.510
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         instead
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.529
#     </td>

# %%
print('Positive' if test_df['is_positive'].iloc[1] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[1], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Positive
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.961</b>, score <b>3.206</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.363
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 97.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.157
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 92.63%); opacity: 0.82" title="-0.011">this</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.22%); opacity: 0.82" title="0.014">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 72.35%); opacity: 0.92" title="0.070">both</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.91%); opacity: 0.81" title="-0.006">an</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 69.88%); opacity: 0.93" title="0.079">entertaining</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.52%); opacity: 0.85" title="0.028">and</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 67.25%); opacity: 0.95" title="0.089">touching</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.96%); opacity: 0.81" title="-0.004">version</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.90%); opacity: 0.80" title="-0.000">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.93%); opacity: 0.81" title="0.006">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 70.63%); opacity: 0.93" title="0.076">classic</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.17%); opacity: 0.86" title="0.034">tale</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 75.88%); opacity: 0.90" title="0.058">also</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 82.51%); opacity: 0.86" title="0.036">quite</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.11%); opacity: 0.85" title="0.032">intelligent</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(0, 100.00%, 84.17%); opacity: 0.85" title="-0.032">not</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.90%); opacity: 0.80" title="-0.000">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.93%); opacity: 0.81" title="0.006">the</span><span style="opacity: 0.80"> &#x27;</span><span style="background-color: hsl(120, 100.00%, 93.29%); opacity: 0.82" title="0.009">me</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.97%); opacity: 0.83" title="0.016">tarzan</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 82.30%); opacity: 0.86" title="0.037">you</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 87.13%); opacity: 0.84" title="0.023">jane</span><span style="opacity: 0.80">&#x27; </span><span style="background-color: hsl(0, 100.00%, 98.61%); opacity: 0.80" title="-0.001">school</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.46%); opacity: 0.82" title="-0.011">at</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.89%); opacity: 0.80" title="0.001">all</span><span style="opacity: 0.80">.  </span><span style="background-color: hsl(120, 100.00%, 84.42%); opacity: 0.85" title="0.031">it</span><span style="opacity: 0.80">&#x27;s </span><span style="background-color: hsl(120, 100.00%, 94.93%); opacity: 0.81" title="0.006">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 87.54%); opacity: 0.84" title="0.022">famous</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.56%); opacity: 0.83" title="0.017">story</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.90%); opacity: 0.80" title ...

# %%
preds = model.predict(test_df['review'])
incorrect_pred_index = np.random.choice(np.where(preds != test_df['is_positive'])[0])

eli5.show_prediction(classifier, test_df['review'].iloc[incorrect_pred_index],
                     vec=vectorizer, targets=['positive'], target_names=['negative', 'positive'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.643</b>, score <b>0.588</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.745
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.29%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.157
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 92.83%); opacity: 0.82" title="0.011">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 68.44%); opacity: 0.94" title="0.091">lives</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.86%); opacity: 0.80" title="-0.000">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.94%); opacity: 0.82" title="-0.013">megan</span><span style="opacity: 0.80">(</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.128">jackie</span><span style="opacity: 0.80"> kresler)</span><span style="background-color: hsl(120, 100.00%, 79.52%); opacity: 0.88" title="0.049">and</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.69%); opacity: 0.84" title="0.027">dylan</span><span style="opacity: 0.80">(</span><span style="background-color: hsl(0, 100.00%, 88.86%); opacity: 0.83" title="-0.021">shane</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 81.30%); opacity: 0.87" title="0.043">elliott</span><span style="opacity: 0.80">)</span><span style="background-color: hsl(120, 100.00%, 77.46%); opacity: 0.89" title="0.056">change</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.82%); opacity: 0.81" title="0.009">in</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.83%); opacity: 0.82" title="0.011">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.12%); opacity: 0.84" title="-0.023">nevada</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.22%); opacity: 0.83" title="-0.022">desert</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.44%); opacity: 0.82" title="0.014">between</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 83.44%); opacity: 0.86" title="-0.036">reno</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 79.52%); opacity: 0.88" title="0.049">and</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.31%); opacity: 0.83" title="-0.017">las</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.46%); opacity: 0.83" title="-0.016">vegas</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(0, 100.00%, 84.48%); opacity: 0.85" title="-0.033">they</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.03%); opacity: 0.80" title="-0.002">stop</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.18%); opacity: 0.83" title="-0.020">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.69%); opacity: 0.83" title="-0.021">eat</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.34%); opacity: 0.83" title="-0.019">at</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 74.53%); opacity: 0.90" title="0.067">small</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.51%); opacity: 0.81" title="-0.006">greasy</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.28%); opacity: 0.81" title="-0.008">spoon</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.11%); opacity: 0.82" title="-0.010">where</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 84.48%); opacity: 0.85" title="-0.033">they</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.08%); opacity: 0.85" title="0.031">reluctantly</sp ...

# %% [markdown]
# Ответ: `TfidfVectorizer` показывает лучшие результаты в сравнении с `CountVectorizer`.

# %% [markdown]
# ### N-граммы слов
#
# До сих пор мы смотрели на тексты как на мешок слов - но очевидно, что есть разница между `good movie` и `not good movie`.
#
# Добавим информацию (хоть какую-то) о последовательностях слов - будем извлекать еще и биграммы слов.
#
# В Vectorizer'ах для этого есть параметр `ngram_range=(n_1, n_2)` - он говорит, что нужны n_1-...n_2-граммы.
#
# **Задание** Попробуйте увеличенный range и поинтерпретируйте полученный результат.

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
classifier = LogisticRegression(max_iter=1000)

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 88.64%

# %% [markdown]
# ### N-граммы символов
#
# Символьные n-граммы дают простой способ выучить полезные корни и суффиксы, не связываясь с этой вашей лингвистикой - только статистика, только хардкор.
#
# Например, слово `badass` мы можем представить в виде такой последовательности триграмм:
#
# `##b #ba bad ada das ass ss# s##`
#
# So interpretable, неправда ли?
#
# Реализовать это дело всё так же просто - нужно поставить `analyzer='char'` в вашем любимом Vectorizer'е и выбрать размер `ngram_range`.
#
# **Задание** Запилите классификатор на n-граммах символов и визуализируйте его.

# %%
vectorizer = TfidfVectorizer(ngram_range=(2, 6), max_features=20000, analyzer='char')
classifier = LogisticRegression(max_iter=1000)

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 87.86%

# %%
print('Positive' if test_df['is_positive'].iloc[1] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[1], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Positive
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.962</b>, score <b>3.244</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.194
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.051
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 94.93%); opacity: 0.81" title="-0.002">t</span><span style="background-color: hsl(120, 100.00%, 98.16%); opacity: 0.80" title="0.000">h</span><span style="background-color: hsl(120, 100.00%, 92.76%); opacity: 0.82" title="0.003">i</span><span style="background-color: hsl(120, 100.00%, 86.81%); opacity: 0.84" title="0.007">s</span><span style="background-color: hsl(120, 100.00%, 81.04%); opacity: 0.87" title="0.011"> </span><span style="background-color: hsl(120, 100.00%, 83.93%); opacity: 0.85" title="0.009">i</span><span style="background-color: hsl(120, 100.00%, 89.70%); opacity: 0.83" title="0.005">s</span><span style="background-color: hsl(120, 100.00%, 92.26%); opacity: 0.82" title="0.003"> </span><span style="background-color: hsl(120, 100.00%, 92.75%); opacity: 0.82" title="0.003">b</span><span style="background-color: hsl(120, 100.00%, 86.27%); opacity: 0.84" title="0.007">o</span><span style="background-color: hsl(120, 100.00%, 81.77%); opacity: 0.87" title="0.011">t</span><span style="background-color: hsl(120, 100.00%, 81.37%); opacity: 0.87" title="0.011">h</span><span style="background-color: hsl(120, 100.00%, 83.23%); opacity: 0.86" title="0.009"> </span><span style="background-color: hsl(120, 100.00%, 91.76%); opacity: 0.82" title="0.003">a</span><span style="background-color: hsl(120, 100.00%, 89.81%); opacity: 0.83" title="0.005">n</span><span style="background-color: hsl(120, 100.00%, 87.11%); opacity: 0.84" title="0.006"> </span><span style="background-color: hsl(120, 100.00%, 82.60%); opacity: 0.86" title="0.010">e</span><span style="background-color: hsl(120, 100.00%, 83.40%); opacity: 0.86" title="0.009">n</span><span style="background-color: hsl(120, 100.00%, 87.88%); opacity: 0.84" title="0.006">t</span><span style="background-color: hsl(120, 100.00%, 83.18%); opacity: 0.86" title="0.009">e</span><span style="background-color: hsl(120, 100.00%, 75.75%); opacity: 0.90" title="0.016">r</span><span style="background-color: hsl(120, 100.00%, 73.19%); opacity: 0.91" title="0.018">t</span><span style="background-color: hsl(120, 100.00%, 76.27%); opacity: 0.89" title="0.016">a</span><span style="background-color: hsl(120, 100.00%, 79.54%); opacity: 0.88" title="0.013">i</span><span style="background-color: hsl(120, 100.00%, 82.17%); opacity: 0.86" title="0.010">n</span><span style="background-color: hsl(120, 100.00%, 88.42%); opacity: 0.83" title="0.006">i</span><span style="background-color: hsl(120, 100.00%, 96.37%); opacity: 0.81" title="0.001">n</span><span style="background-color: hsl(120, 100.00%, 97.00%); opacity: 0.80" title="0.001">g</span><span style="background-color: hsl(120, 100.00%, 92.90%); opacity: 0.82" title="0.003"> </span><span style="background-color: hsl(120, 100.00%, 86.29%); opacity: 0.84" title="0.007">a</span><span style="background-color: hsl(120, 100.00%, 81.53%); opacity: 0.87" title="0.011">n</span><span style="background-color: hsl(120, 100.00%, 86.24%); opacity: 0.84" title="0.007">d</span><span style="background-color: hsl(120, 100.00%, 94.02%); opacity: 0.81" title="0.002"> </span><span style="background-color: hsl(120, 100.00%, 98.85%); opacity: 0.80" title="0.000">a</span><span style="background-color: hsl(120, 100.00%, 88.20%); opacity: 0.83" title="0.006"> </span><span style="background-color: hsl(120, 100.00%, 79.57%); opacity: 0.88" title="0.013">t</span><span style="background-color: hsl(120, 100.00%, 73.75%); opacity: 0.91" title="0.018">o</span><span style="background-color: hsl(120, 100.00%, 73.15%); opacity: 0.91" title="0.018">u</span><span style="background-color: hsl(120, 100.00%, 80.55%); opacity: 0.87" title="0.012">c</span><span style="background-color: hsl(120, 100.00%, 89.33%); opacity: 0.83" title="0.005">h</span><span style="background-color: hsl(0, 100.00%, 90.56%); opacity: 0.83" title="-0.004">i</span><span style="background-color: hsl(0, 100.00%, 87.40%); opacity: 0.84" title="-0.006">n</span><span ...

# %% [markdown]
# ## Подключаем лингвистику

# %% [markdown]
# ### Лемматизация и стемминг
#
# Если присмотреться, можно найти формы одного слова с разной семантической окраской по мнению классификатора. Или нет?
#
# **Задание** Найти формы слова с разной семантической окраской.
#
# Поверя, что они есть, попробуем что-нибудь с этим сделать.
#
# Например, лемматизируем - сведем к начальной форме все слова. Поможет в этом библиотека spacy.

# %%
import spacy
from spacy import displacy

nlp = spacy.load('en_core_web_sm', disable=['parser'])

docs = [doc for doc in nlp.pipe(train_df.review.values[:50])]

# %%
for token in docs[0]:
    print(token.text, token.lemma_, token.ent_iob_, token.ent_type_)
# Out:
# Dreamgirls dreamgirl B ORG
# , , O
# despite despite O
# its its O
# fistful fistful O
# of of O
# Tony Tony B PERSON
# wins win O
# in in O
# an an B DATE
# incredibly incredibly I DATE
# weak weak I DATE
# year year I DATE
# on on O
# Broadway Broadway B FAC
# , , O
# has have O
# never never O
# been be O
# what what O
# one one O
# would would O
# call call O
# a a O
# jewel jewel O
# in in O
# the the O
# crown crown O
# of of O
# stage stage O
# musicals musical O
# . . O
# However however O
# , , O
# that that O
# is be O
# not not O
# to to O
# say say O
# that that O
# in in O
# the the O
# right right O
# cinematic cinematic O
# hands hand O
# it it O
# could could O
# not not O
# be be O
# fleshed flesh O
# out out O
# and and O
# polished polish O
# into into O
# something something O
# worthwhile worthwhile O
# on on O
# - - O
# screen screen O
# . . O
# Unfortunately unfortunately O
# , , O
# what what O
# transfers transfer O
# to to O
# the the O
# screen screen O
# is be O
# basically basically O
# a a O
# slavishly slavishly O
# faithful faithful O
# version version O
# of of O
# the the O
# stage stage O
# hit hit O
# with with O
# all all O
# of of O
# its its O
# inherent inherent O
# weaknesses weakness O
# intact intact O
# . . O
# First first B ORDINAL
# , , O
# the the O
# score score O
# has have O
# never never O
# been be O
# one one O
# of of O
# the the O
# strong strong O
# points point O
# of of O
# this this O
# production production O
# and and O
# the the O
# film film O
# does do O
# not not O
# change change O
# that that O
# factor factor O
# . . O
# There there O
# are be O
# lots lot O
# of of O
# songs song O
# ( ( O
# perhaps perhaps O
# too too O
# many many O
# ? ? O
# ) ) O
# , , O
# but but O
# few few O
# of of O
# them they O
# are be O
# especially especially O
# memorable memorable O
# . . O
# The the O
# closest close O
# any any O
# come come O
# to to O
# catchy catchy O
# tunes tune O
# are be O
# the the O
# title title O
# song song O
# and and O
# One one B CARDINAL
# Night night O
# Only only O
# - - O
# the the O
# much much O
# acclaimed acclaimed O
# And and O
# I I O
# Am be O
# Telling tell O
# You you O
# That that O
# I I O
# Am be O
# Not not O
# Going go O
# is be O
# less less O
# a a O
# great great O
# song song O
# than than O
# it it O
# is be O
# a a O
# dramatic dramatic O
# set set O
# piece piece O
# for for O
# the the O
# character character O
# of of O
# Effie Effie B ORG
# ( ( O
# Jennifer Jennifer B PERSON
# Hudson Hudson I PERSON
# ) ) O
# . . O
# The the O
# film film O
# is be O
# slick slick O
# and and O
# technically technically O
# well well O
# - - O
# produced produce O
# , , O
# but but O
# the the O
# story story O
# and and O
# characters character O
# are be O
# surprisingly surprisingly O
# thin thin O
# and and O
# lacking lack O
# in in O
# any any O
# resonance resonance O
# . . O
# There there O
# is be O
# some some O
# interest interest O
# in in O
# the the O
# opening opening O
# moments moment O
# , , O
# watching watch O
# Jamie Jamie B PERSON
# Foxx Foxx I PERSON
# 's 's I PERSON
# Svengali Svengali O
# - - O
# like like O
# manager manager O
# manipulate manipulate O
# his his O
# acts act O
# to to O
# the the O
# top top O
# , , O
# but but O
# that that O
# takes take O
# a a O
# back back O
# seat seat O
# in in O
# the the O
# latter latter O
# portion portion O
# of of O
# the the O
# film film O
# , , O
# when when O
# the the O
# story story O
# conveniently conveniently O
# tries try O
# to to O
# cast cast O
# him he O
# as as O
# a a O
# villain villain O
# , , O
# despite despite O
# his his O
# having have O
# been be O
# right right O
# from from O
# a a O
# business business O
# stand stand O
# - - O
# point point O
# for for O
# a a O
# good good O
# majority majority O
# of of O
# the the O
# film film O
# . . O
# Beyonce Beyonce B PERSON
# Knowles Knowles I PERSON
# is be O
# lovely lovely O
# and and O
# sings sing O
# her her O
# songs song O
# perfectly perfectly O
# well well O
# , , O
# but but O
# is be O
# stuck stick O
# with with O
# a a O
# character character O
# who who O
# is be O
# basically basically O
# all all O
# surface surface O
# glitz glitz O
# . . O
# Anika Anika B PERSON
# Noni Noni I PERSON
# Rose Rose I PERSON
# as as O
# the the O
# third third B ORDINAL
# member member O
# of of O
# the the O
# Dreamgirls Dreamgirls B ORG
# trio trio O
# literally literally O
# has have O
# nothing nothing O
# to to O
# do do O
# for for O
# the the O
# entire entire O
# film film O
# . . O
# Eddie Eddie B PERSON
# Murphy Murphy I PERSON
# acquits acquit O
# himself himself O
# well well O
# as as O
# a a O
# singer singer O
# obviously obviously O
# based base O
# on on O
# James James B PERSON
# Brown Brown I PERSON
# , , O
# but but O
# the the O
# role role O
# is be O
# not not O
# especially especially O
# meaty meaty O
# and and O
# ultimately ultimately O
# has have O
# little little O
# impact impact O
# . . O
# Foxx Foxx O
# would would O
# seem seem O
# ideal ideal O
# casting casting O
# , , O
# but but O
# he he O
# seems seem O
# oddly oddly O
# withdrawn withdraw O
# and and O
# bored bored O
# . . O
# The the O
# film film O
# 's 's O
# biggest big O
# selling selling O
# point point O
# is be O
# surely surely O
# former former O
# American American B ORG
# Idol Idol I ORG
# contestant contestant O
# / / O
# Oscar Oscar O
# winner winner O
# Jennifer Jennifer B PERSON
# Hudson Hudson I PERSON
# in in O
# the the O
# central central O
# role role O
# of of O
# Effie Effie B ORG
# White White O
# , , O
# the the O
# temperamental temperamental O
# singer singer O
# who who O
# gets get O
# booted boot O
# from from O
# the the O
# group group O
# and and O
# makes make O
# a a O
# triumphant triumphant O
# closing closing O
# act act O
# return return O
# . . O
# For for O
# me I O
# , , O
# Effie Effie B ORG
# has have O
# always always O
# been be O
# a a O
# big big O
# problem problem O
# in in O
# both both O
# the the O
# show show O
# and and O
# the the O
# movie movie O
# . . O
# The the O
# film film O
# obviously obviously O
# wants want O
# you you O
# to to O
# feel feel O
# sorry sorry O
# for for O
# her she O
# and and O
# rather rather O
# ham ham O
# - - O
# handedly handedly O
# takes take O
# her her O
# side side O
# , , O
# but but O
# I I O
# have have O
# never never O
# been be O
# sure sure O
# that that O
# this this O
# character character O
# deserves deserve O
# that that O
# kind kind O
# of of O
# devotion devotion O
# . . O
# From from O
# the the O
# start start O
# , , O
# Effie Effie B ORG
# conducts conduct O
# herself herself O
# for for O
# the the O
# most most O
# part part O
# like like O
# an an O
# obnoxious obnoxious O
# , , O
# egotistical egotistical O
# , , O
# self self O
# - - O
# centered center O
# diva diva O
# , , O
# who who O
# is be O
# more more O
# interested interested O
# in in O
# what what O
# everyone everyone O
# else else O
# can can O
# do do O
# for for O
# her she O
# rather rather O
# than than O
# having have O
# much much O
# vested vested O
# interest interest O
# in in O
# the the O
# group group O
# of of O
# which which O
# she she O
# is be O
# a a O
# part part O
# . . O
# When when O
# she she O
# is be O
# booted boot O
# from from O
# the the O
# group group O
# for for O
# her her O
# unprofessionalism unprofessionalism O
# and and O
# bad bad O
# attitude attitude O
# , , O
# the the O
# charges charge O
# are be O
# more more O
# than than O
# well well O
# - - O
# founded found O
# , , O
# but but O
# the the O
# stage stage O
# show show O
# / / O
# film film O
# seem seem O
# to to O
# think think O
# Effie Effie B ORG
# should should O
# be be O
# cut cut O
# unlimited unlimited O
# slack slack O
# simply simply O
# because because O
# she she O
# has have O
# a a O
# great great O
# voice voice O
# . . O
# Even even O
# though though O
# the the O
# film film O
# tries try O
# to to O
# soften soften O
# some some O
# of of O
# Effie Effie B ORG
# 's 's O
# harder hard O
# edges edge O
# to to O
# make make O
# her she O
# more more O
# likable likable O
# , , O
# the the O
# charges charge O
# still still O
# stand stand O
# . . O
# Her her O
# story story O
# becomes become O
# more more O
# manipulative manipulative O
# by by O
# suggesting suggest O
# she she O
# should should O
# have have O
# our our O
# further further O
# sympathy sympathy O
# because because O
# she she O
# is be O
# an an O
# unwed unwed O
# mother mother O
# struggling struggle O
# to to O
# raise raise O
# her her O
# daughter daughter O
# - - O
# using use O
# the the O
# implication implication O
# that that O
# ( ( O
# much much O
# like like O
# the the O
# talent talent O
# card card O
# ) ) O
# motherhood motherhood O
# immediately immediately O
# makes make O
# any any O
# behavior behavior O
# excusable excusable O
# . . O
# Indeed indeed O
# the the O
# only only O
# big big O
# effort effort O
# the the O
# film film O
# makes make O
# to to O
# show show O
# Effie Effie B ORG
# 's 's O
# mothering mothering O
# is be O
# to to O
# tell tell O
# us we O
# about about O
# it it O
# and and O
# then then O
# include include O
# a a O
# scene scene O
# where where O
# she she O
# barks bark O
# at at O
# her her O
# daughter daughter O
# in in O
# the the O
# unemployment unemployment O
# office office O
# , , O
# insists insist O
# that that O
# the the O
# girl girl O
# has have O
# " " O
# no no O
# father father O
# " " O
# and and O
# then then O
# refuse refuse O
# to to O
# look look O
# for for O
# gainful gainful O
# employment employment O
# to to O
# support support O
# them they O
# since since O
# singing singing O
# is be O
# all all O
# she she O
# knows know O
# . . O
# In in O
# the the O
# hands hand O
# of of O
# a a O
# skillful skillful O
# actress actress O
# , , O
# the the O
# gaps gap O
# could could O
# perhaps perhaps O
# have have O
# been be O
# remedied remedied O
# with with O
# technique technique O
# and and O
# charisma charisma O
# . . O
# Unfortunately unfortunately O
# , , O
# Hudson Hudson B PERSON
# is be O
# not not O
# that that O
# actress actress O
# . . O
# She she O
# sings sing O
# well well O
# , , O
# but but O
# the the O
# dialog dialog O
# - - O
# driven drive O
# moments moment O
# do do O
# not not O
# come come O
# naturally naturally O
# to to O
# her she O
# nor nor O
# do do O
# high high O
# emotional emotional O
# moments moment O
# . . O
# Effie Effie B ORG
# 's 's O
# signature signature O
# moment moment O
# ( ( O
# the the O
# aforementioned aforementione O
# And and O
# I I O
# Am be O
# Telling tell O
# You you O
# ... ... O
# number number O
# ) ) O
# is be O
# well well O
# - - O
# sung sing O
# by by O
# Hudson Hudson B PERSON
# , , O
# but but O
# emotionally emotionally O
# flat flat O
# in in O
# the the O
# acting act O
# department department O
# . . O
# Effie Effie B ORG
# is be O
# supposed suppose O
# to to O
# expressing express O
# her her O
# rage rage O
# and and O
# desperation desperation O
# at at O
# her her O
# predicament predicament O
# , , O
# but but O
# Hudson Hudson B PERSON
# comes come O
# off off O
# as as O
# a a O
# cabaret cabaret O
# performer performer O
# belting belt O
# out out O
# a a O
# hot hot O
# number number O
# . . O
# All all O
# in in O
# all all O
# , , O
# not not O
# quite quite O
# the the O
# emotional emotional O
# highlight highlight O
# one one O
# expects expect O
# . . O
# The the O
# latter latter O
# portion portion O
# of of O
# the the O
# film film O
# is be O
# basically basically O
# a a O
# predictable predictable O
# melange melange O
# of of O
# events event O
# that that O
# maneuver maneuver O
# Foxx Foxx B ORG
# into into O
# Hudson Hudson B ORG
# 's 's O
# earlier early O
# position position O
# and and O
# allow allow O
# her she O
# to to O
# strut strut O
# back back O
# in in O
# and and O
# lord lord O
# it it O
# over over O
# everyone everyone O
# . . O
# Foxx Foxx B ORG
# 's 's O
# criminal criminal O
# offenses offense O
# in in O
# the the O
# film film O
# are be O
# undoubtedly undoubtedly O
# par par O
# for for O
# the the O
# course course O
# of of O
# many many O
# struggling struggle O
# record record O
# producers producer O
# , , O
# but but O
# the the O
# film film O
# 's 's O
# seeming seeming O
# implication implication O
# that that O
# he he O
# has have O
# it it O
# coming come O
# because because O
# he he O
# helped help O
# usher usher O
# in in O
# the the O
# disco disco O
# era era O
# is be O
# rather rather O
# ridiculous ridiculous O
# , , O
# not not O
# to to O
# mention mention O
# pretentious pretentious O
# and and O
# condescending condescend O
# , , O
# particularly particularly O
# coming come O
# from from O
# a a O
# film film O
# with with O
# all all O
# of of O
# the the O
# depth depth O
# of of O
# a a O
# puddle puddle O
# . . O
# The the O
# end end O
# result result O
# is be O
# a a O
# faithful faithful O
# rendition rendition O
# of of O
# the the O
# stage stage O
# hit hit O
# , , O
# drained drain O
# of of O
# emotion emotion O
# , , O
# energy energy O
# or or O
# anything anything O
# that that O
# can can O
# be be O
# described describe O
# as as O
# dynamic dynamic O
# . . O

# %% [markdown]
# Весь этот процесс очень долгий, поэтому я предподсчитал всё.

# %%
import pickle

with open('train_docs.pkl', 'rb') as f:
    train_docs = pickle.load(f)
    
with open('test_docs.pkl', 'rb') as f:
    test_docs = pickle.load(f)

# %% [markdown]
# **Задание** Сделайте классификатор на лемматизированных текстах.

# %%
def lemmatize(text):
    doc = nlp(text)
    return ' '.join([token.lemma_ for token in doc])

train_df['lemmatized_review'] = train_df['review'].apply(lemmatize)
test_df['lemmatized_review'] = test_df['review'].apply(lemmatize)
train_df.head()
# Out:
#    is_positive                                             review  \
# 0            0  Dreamgirls, despite its fistful of Tony wins i...
# 1            0  This show comes up with interesting locations ...
# 2            1  I simply love this movie. I also love the Ramo...
# 3            0  Spoilers ahead if you want to call them that.....
# 4            1  My all-time favorite movie! I have seen many m...
#
#                                    lemmatized_review
# 0  dreamgirl , despite its fistful of Tony win in...
# 1  this show come up with interesting location as...
# 2  I simply love this movie . I also love the Ram...
# 3  spoiler ahead if you want to call they that .....
# 4  my all - time favorite movie ! I have see many...

# %%
def eval_model(model, inp_data, true_labels):
    preds = model.predict(inp_data)
    print('Test accuracy = {:.2%}'.format(accuracy_score(true_labels, preds)))

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
classifier = LogisticRegression(max_iter=1000)

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['lemmatized_review'], train_df['is_positive'])

eval_model(model, test_df['lemmatized_review'], test_df['is_positive'])
# Out:
# Test accuracy = 88.77%

# %% [markdown]
# Более простой способ нормализации слов - использовать стемминг. Он немного тупой, не учитывает контекст, но иногда оказывается даже эффективнее лемматизации - а, главное, быстрее.
#
# По сути это просто набор правил, как обрезать слово, чтобы получить основу (stem):

# %%
from nltk import PorterStemmer

stemmer = PorterStemmer()

print(stemmer.stem('become'))
print(stemmer.stem('becomes'))
print(stemmer.stem('became'))
# Out:
# becom
# becom
# becam

# %% [markdown]
# **Задание** Попробуйте вместо лемм классифицировать основы.

# %%
from functools import lru_cache

@lru_cache(maxsize=None)
def stem_word(word):
    return stemmer.stem(word)

def stem(text):
    words = text.split()
    return ' '.join([stem_word(word) for word in words])

# %%
train_df['stemed_review'] = train_df['review'].apply(stem)
test_df['stemed_review'] = test_df['review'].apply(stem)
train_df.head()
# Out:
#    is_positive                                             review  \
# 0            0  Dreamgirls, despite its fistful of Tony wins i...
# 1            0  This show comes up with interesting locations ...
# 2            1  I simply love this movie. I also love the Ramo...
# 3            0  Spoilers ahead if you want to call them that.....
# 4            1  My all-time favorite movie! I have seen many m...
#
#                                    lemmatized_review  \
# 0  dreamgirl , despite its fistful of Tony win in...
# 1  this show come up with interesting location as...
# 2  I simply love this movie . I also love the Ram...
# 3  spoiler ahead if you want to call they that .....
# 4  my all - time favorite movie ! I have see many...
#
#                                        stemed_review
# 0  dreamgirls, despit it fist of toni win in an i...
# 1  thi show come up with interest locat as fast a...
# 2  i simpli love thi movie. i also love the ramon...
# 3  spoiler ahead if you want to call them that......
# 4  my all-tim favorit movie! i have seen mani mov...

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
classifier = LogisticRegression(max_iter=1000)

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['stemed_review'], train_df['is_positive'])

eval_model(model, test_df['stemed_review'], test_df['is_positive'])
# Out:
# Test accuracy = 88.28%

# %% [markdown]
# ### NER
#
# В текстах рецензий очень много именованных сущностей. Вот, например:

# %%
displacy.render(docs[0], style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dreamgirls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , despite its fistful of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wins in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     an incredibly weak year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  on
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Broadway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , has never been what one would call a jewel in the crown of stage musicals. However, that is not to say that in the right cinematic hands it could not be fleshed out and polished into something worthwhile on-screen. Unfortunately, what transfers to the screen is basically a slavishly faithful version of the stage hit with all of its inherent weaknesses intact.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# , the score has never been one of the strong points of this production and the film does not change that factor. There are lots of songs (perhaps too many?), but few of them are especially memorable. The closest any come to catchy tunes are the title song and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Night Only - the much acclaimed And I Am Telling You That I Am Not Going is less a great song than it is a dramatic set piece for the character of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Effie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jennifer Hudson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ). The film is slick and technically well-produced, but the story and characters are surprisingly thin and lacking in any resonance. There is some interest in the opening moments, watching
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jamie Foxx's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Svengali-like manager manipulate his acts to the top, but that takes a back seat in the latter portion of the film, when the story conveniently tries to cast him as a villain, despite his having been right from a business stand-point for a good majority of the film.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beyonce Knowles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is lovely and sings her songs perfectly well, but is stuck with a character who is basically all surface glitz.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anika Noni Rose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  member of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dreamgirls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  trio literally has nothing to do for the entire film.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eddie Murphy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  acquits himself well as a singer obviously based on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James Brown
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , but the role is not especially meaty and ultimately has little impact. Foxx would seem ideal casting, but he seems oddly withdrawn and bored. The film's biggest selling point is surely former
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American Idol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contestant/Oscar winner
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jennifer Hudson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in the central role of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Effie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  White, the temperamental singer who gets booted from the group and makes a triumphant closing act return. For me,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Effie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has always been a big problem in both the show and the movie. The film obviously wants you to feel sorry for her and rather ham-handedly takes her side, but I have never been sure that this character deserves that kind of

# %% [markdown]
# Вообще говоря, почему вдруг какой-нибудь Депп должен нести семантическую окраску? Однако оказывается, что классификатор выучивает, что какие-то имена чаще в положительных рецензиях - или наоборот. Это похоже на переобучение - почему бы не попробовать вырезать сущности?
#
# **Задание** Удалите из текстов какие-то из сущностей, пользуясь координатами из запикленных файлов. Описание сущностей можно посмотреть [здесь](https://spacy.io/api/annotation#named-entities). Запустите классификатор.

# %%
@lru_cache(maxsize=None)
def del_tags(text):
    tags = ['PERSON', 'ORG']

    doc = nlp(text)
    tokens=[token.text for token in doc if token.ent_type_ not in tags]
    return ' '.join(tokens)

train_df['lemmatized_review_cleared'] = train_df['lemmatized_review'].apply(del_tags)
test_df['lemmatized_review_cleared'] = test_df['lemmatized_review'].apply(del_tags)
train_df.head()
# Out:
#    is_positive                                             review  \
# 0            0  Dreamgirls, despite its fistful of Tony wins i...
# 1            0  This show comes up with interesting locations ...
# 2            1  I simply love this movie. I also love the Ramo...
# 3            0  Spoilers ahead if you want to call them that.....
# 4            1  My all-time favorite movie! I have seen many m...
#
#                                    lemmatized_review  \
# 0  dreamgirl , despite its fistful of Tony win in...
# 1  this show come up with interesting location as...
# 2  I simply love this movie . I also love the Ram...
# 3  spoiler ahead if you want to call they that .....
# 4  my all - time favorite movie ! I have see many...
#
#                                        stemed_review  \
# 0  dreamgirls, despit it fist of toni win in an i...
# 1  thi show come up with interest locat as fast a...
# 2  i simpli love thi movie. i also love the ramon...
# 3  spoiler ahead if you want to call them that......
# 4  my all-tim favorit movie! i have seen mani mov...
#
#                            lemmatized_review_cleared
# 0  dreamgirl , despite its fistful of win in an i...
# 1  this show come up with interesting location as...
# 2  I simply love this movie . I also love the , s...
# 3  spoiler ahead if you want to call they that .....
# 4  my all - time favorite movie ! I have see many...

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['lemmatized_review_cleared'], train_df['is_positive'])

eval_model(model, test_df['lemmatized_review_cleared'], test_df['is_positive'])
# Out:
# Test accuracy = 88.92%

# %% [markdown]
# ## Включаем дип лёрнинг

# %% [markdown]
# Мы тут пришли deep learning'ом заниматься, а делаем почему-то модель на логистической регрессии. Как так?
#
# Попробуем запустить относительно стандартную модель для классификации текстов - сверточная сеть поверх словных эмбеддингов.
#
# Разбираться, что это за зверь, будем на следующих занятиях, а пока будем просто им пользоваться :)
#
# Каждое предложение нужно представлять набором слов - и сразу же начинаются проблемы. Во-первых, как ограничить длину предложения?
#
# Прикинем по гистограмме, какая длина нам подходит:

# %%
train_df['review']
# Out:
# 0        Dreamgirls, despite its fistful of Tony wins i...
# 1        This show comes up with interesting locations ...
# 2        I simply love this movie. I also love the Ramo...
# 3        Spoilers ahead if you want to call them that.....
# 4        My all-time favorite movie! I have seen many m...
#                                ...
# 24995    I am a big fan of the movie, but not for the u...
# 24996    I'm not going to bother with a plot synopsis s...
# 24997    This movie . . . I don't know. Why they would ...
# 24998    Saw this film on DVD yesterday and was gob-sma...
# 24999    This was a disappointment - none of the nuance...
# Name: review, Length: 25000, dtype: object

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

_, _, hist = plt.hist(train_df.review.apply(lambda text: len(text.split())), bins='auto')
hist
# Out:
# <BarContainer object of 231 artists>

# %% [markdown]
# Кроме этого, нужно перенумеровать как-то слова.

# %%
from collections import Counter

words_counter = Counter((word for text in train_df.review for word in text.lower().split()))

word2idx = {
    '': 0,
    '<unk>': 1
}
for word, count in words_counter.most_common():
    if count < 10:
        break
        
    word2idx[word] = len(word2idx)
    
print('Words count', len(word2idx))
# Out:
# Words count 26783

# %% [markdown]
# **Задание** Сконвертируйте данные

# %%
def convert(texts, word2idx, max_text_len):
    data = np.zeros((len(texts), max_text_len), dtype=int)
    
    for inx, text in enumerate(texts):
        result = []
        for word in text.split():
            if word in word2idx:
                result.append(word2idx[word])
        padding = [0]*(max_text_len - len(result))
        data[inx] = np.array(padding + result[-max_text_len:], dtype=int)
    return data

X_train = convert(train_df.review, word2idx, 1000)
X_test = convert(test_df.review, word2idx, 1000)

# %% [markdown]
# Поставим учиться модельку на keras.
#
# *Напоминание*: на keras, чтобы обучить модель, нужно
# 1. Определить модель, например:
# ```python
# model = Sequential()
# model.add(Dense(1, activation='sigmoid', input_dim=NUM_WORDS))
# ```
# 2. Задать функцию потерь и оптимизатор:
# ```python
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# ```
#
# 3. Запустить обучение:
# ```python
# model.fit(X_train, y_train,
#           batch_size=32,
#           epochs=3,
#           validation_data=(X_test, y_test))
# ```
#
# В NLP чаще всего ставятся задачи классификации, поэтому нужно запомнить такие функции потерь:
#
# *   **categorical_crossentropy** - для многоклассовой классификации, в качестве меток должны передаваться one-hot-encoding вектора
# *   **sparse_categorical_crossentropy** - аналогично предыдущему, но в качестве меток нужно передавать просто индексы соответствующих классов
# *   **binary_crossentropy** - для бинарной классификации
#
#
# В качестве оптимизатора обычно используют `sgd` или `adam`.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.11.0'

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalMaxPooling1D, Dropout

# %%
model = Sequential([
    Embedding(input_dim=len(word2idx), output_dim=64, input_shape=(X_train.shape[1],)),
    GlobalMaxPooling1D(),
    Dense(units=10, activation='relu'),
    Dense(units=10, activation='relu'),
    
    Dense(units=1, activation='sigmoid')
])

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1000, 64)          1714112
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 10)                650
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1,714,883
# Trainable params: 1,714,883
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, train_df.is_positive, batch_size=128, epochs=10, 
          validation_data=(X_test, test_df.is_positive))
# Out:
# Epoch 1/10
# 196/196 [==============================] - 9s 42ms/step - loss: 0.6377 - accuracy: 0.6800 - val_loss: 0.4701 - val_accuracy: 0.8295
# Epoch 2/10
# 196/196 [==============================] - 8s 41ms/step - loss: 0.3148 - accuracy: 0.8788 - val_loss: 0.2971 - val_accuracy: 0.8736
# Epoch 3/10
# 196/196 [==============================] - 8s 42ms/step - loss: 0.1838 - accuracy: 0.9332 - val_loss: 0.2897 - val_accuracy: 0.8787
# Epoch 4/10
# 196/196 [==============================] - 8s 41ms/step - loss: 0.1054 - accuracy: 0.9672 - val_loss: 0.3160 - val_accuracy: 0.8751
# Epoch 5/10
# 196/196 [==============================] - 8s 42ms/step - loss: 0.0535 - accuracy: 0.9870 - val_loss: 0.3578 - val_accuracy: 0.8712
# Epoch 6/10
# 196/196 [==============================] - 8s 41ms/step - loss: 0.0241 - accuracy: 0.9962 - val_loss: 0.3931 - val_accuracy: 0.8713
# Epoch 7/10
# 196/196 [==============================] - 8s 42ms/step - loss: 0.0105 - accuracy: 0.9990 - val_loss: 0.4262 - val_accuracy: 0.8706
# Epoch 8/10
# 196/196 [==============================] - 8s 41ms/step - loss: 0.0050 - accuracy: 0.9995 - val_loss: 0.4561 - val_accuracy: 0.8701
# Epoch 9/10
# 196/196 [==============================] - 8s 42ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.4824 - val_accuracy: 0.8698
# Epoch 10/10
# 196/196 [==============================] - 8s 41ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.5028 - val_accuracy: 0.8695

# %% [markdown]
# **Задание** Подсчитайте качество модели на тесте

# %%
loss, accuracy = model.evaluate(X_test, test_df.is_positive)
print("Test loss {:.4f}, accuracy {:.2f}%".format(loss, accuracy * 100))
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.5028 - accuracy: 0.8695
# Test loss 0.5028, accuracy 86.95%
